# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovgr/Aulas_Progama-oFPB/blob/main/Aula01_Phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Meu primeiro Notebook de Phyton

# %%
print("Palmeiras é o melhor time do mundo!")
# Out:
# Palmeiras é o melhor time do mundo!

# %%
#Variáveis
nome = "Palmeiras"
print (nome)
# Out:
# Palmeiras

# %%
#Operações com varoiáveis
a = 5
b = 30
soma  = a + b
subtracao = a - b
multipli = a * b
divisao = a / b

# %%
print (soma)
print (divisao)
print (multipli)
print (subtracao)
# Out:
# 35
# 0.16666666666666666
# 150
# -25

# %% [markdown]
# #Dobro

# %%
a = 20
b = 60
c = 25
dobro  = a * 2
print (dobro)
# Out:
# 40

# %% [markdown]
# #Média

# %%
nota1 = 7.2
nota2 = 7.9
nota3 = 9.8

media = (nota1 + nota2 + nota3) /3

print (f'{media:,.2f}')
# Out:
# 8.30

# %% [markdown]
# #Idade

# %%
nascimento = 2002
idd = 2023 - 2002
print (idd)
# Out:
# 21

# %% [markdown]
# #Trabalhando com input

# %%
nome = int(input("Digite aqui o número 😉: "))
print()
rstd = nome * 3
print('O resultado é ' , rstd)
# Out:
# Digite aqui o número 😉: 54
#
# O resultado é  162
